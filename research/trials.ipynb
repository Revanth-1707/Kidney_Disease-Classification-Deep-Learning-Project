# %%
import gdown

# %%
url = 'https://drive.google.com/file/d/169D9VzYXm4XRSVlet4IuxQ65fnssKxEP/view?usp=sharing'

# %%
file_id = url.split('/')[-2]

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix + file_id, 'kidney-CT-Scan-data.zip')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=169D9VzYXm4XRSVlet4IuxQ65fnssKxEP
# From (redirected): https://drive.google.com/uc?id=169D9VzYXm4XRSVlet4IuxQ65fnssKxEP&confirm=t&uuid=1c0269c3-42c9-4776-bc31-2a39039c36aa
# To: c:\Users\Revanth L\OneDrive\Pictures\Desktop\AI\DL\Project\Kidney_Disease-Classification-Deep-Learning-Project\research\kidney-CT-Scan-data.zip
# 100%|██████████| 1.63G/1.63G [13:24<00:00, 2.02MB/s]
# 'kidney-CT-Scan-data.zip'
